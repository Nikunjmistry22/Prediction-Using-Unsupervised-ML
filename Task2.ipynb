# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikunjmistry22/Prediction-Using-Unsupervised-ML/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Science and Business Analytics Intern @ The Sparks Foundation**
# **Nikunj Mistry : Task 2 - Prediction Using Unsupervised ML**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# %% [markdown]
# **Load dataset**

# %%
#load dataset
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
iris_df.head() # See the first 5 rows
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris_df.shape
# Out:
# (150, 4)

# %% [markdown]
# integer-location based indexing for selection by position

# %%
x = iris_df.iloc[:, [0, 1, 2, 3]].values

# %%
# Finding the optimum number of clusters for k-means classification

from sklearn.cluster import KMeans
a = [] # Within cluster sum of squares

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    a.append(kmeans.inertia_)

# %% [markdown]
# **Line graph**

# %%
plt.plot(range(1, 11), a)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('a')
plt.show()

# %% [markdown]
# The optimum clusters is where the elbow occurs. Within cluster sum of squares (WCSS) represented by var ('a') doesn't decrease significantly with every iteration.
#
# **Hence here we choose the number of clusters as 3.**

# %% [markdown]
# # **KMean Classifier on the datasets**

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++',
                max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %% [markdown]
# #**Visualising the clusters - On the first two columns**

# %%
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], 
            s = 100, c = 'purple', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], 
            s = 100, c = 'yellow', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],
            s = 100, c = 'cyan', label = 'Iris-virginica')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'red', label = 'Centroids')

plt.legend()

# %% [markdown]
# #**Seperating the centroids of the clusters**

# %%
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'black', label = 'Centroids')
plt.legend()

# %% [markdown]
# #**Conclusion**

# %% [markdown]
# The optimum number of clusters: 3
#
# Data Visualization:
#
# ![task2.png](data:image/png;base64,...)
